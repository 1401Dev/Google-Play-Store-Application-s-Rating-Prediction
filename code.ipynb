# %% [markdown]
# # **Pre-Processing**

# %%
import pandas as pd
import numpy as np

# %%
# import files
from google.colab import files
files = files.upload()

# creating a dataframe
df = pd.read_csv('/content/Apps_info - Copy.csv')
df.head()
# Out:
#      <input type="file" id="files-c97cae2d-7d90-4879-9b78-5ae8321cf204" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c97cae2d-7d90-4879-9b78-5ae8321cf204">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# generating descriptive statistics
df.describe(include='all')
# Out:
#               name category       rating    no_reviews              sizeMB  \
# count         5109     5109  4459.000000  5.109000e+03                2277
# unique        4381       16          NaN           NaN                 263
# top     Bowmasters     GAME          NaN           NaN  Varies with device
# freq             6     1130          NaN           NaN                 398
# mean           NaN      NaN     4.209621  5.280271e+05                 NaN
# std            NaN      NaN     0.518270  3.242245e+06                 NaN
# min            NaN      NaN     1.000000  0.000000e+00                 NaN
# 25%            NaN      NaN     4.000000  5.700000e+01                 NaN
# 50%            NaN      NaN     4.300000  4.253000e+03                 NaN
# 75%            NaN      NaN     4.500000  7.912900e+04                 NaN
# max            NaN      NaN     5.000000  7.815831e+07                 NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5109 entries, 0 to 5108
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     5109 non-null   object
#  1   category                 5109 non-null   object
#  2   rating                   4459 non-null   float64
#  3   no_reviews               5109 non-null   int64
#  4   sizeMB                   2277 non-null   object
#  5   size                     5109 non-null   object
#  6   no_of_installs           5109 non-null   object
#  7   type                     5109 non-null   object
#  8   price                    5109 non-null   object
#  9   content_rating           5109 non-null   object
#  10  genres                   5109 non-null   object
#  11  last_updt                5109 non-null   object
#  12  current_ver              5108 non-null   object
#  13  android_ver              5109 non-null   object
# ...

# %% [markdown]
# *******************************************************************************

# %% [markdown]
# **DATA CLEANING**

# %%
# Changing the datatype of variable
df['name'] = df['name'].astype('string')

# %%
# Changing the datatype of variable
df['category'] = df['category'].astype('string')

# %%
# Replacing the values
df['sizeMB'] = df['sizeMB'].replace(['Varies with device'], ['0'])

# Changing the datatype of variable
df['sizeMB'] = df['sizeMB'].astype('float')

# %%
# CHECKING THE NULL VALUES
  
# missing values (mv) in dataset
mv = df.isnull()  # isnull() is used to detect missing values
mv

tlt_null = mv.sum()

# percentage of null values in dataset
percent = tlt_null*100 / len(df)
percent
# Out:
# name                        0.000000
# category                    0.000000
# rating                     12.722646
# no_reviews                  0.000000
# sizeMB                     55.431591
# size                        0.000000
# no_of_installs              0.000000
# type                        0.000000
# price                       0.000000
# content_rating              0.000000
# genres                      0.000000
# last_updt                   0.000000
# current_ver                 0.019573
# android_ver                 0.000000
# ref_date                    0.000000
# no_of_days_after_update     0.000000
# dtype: float64

# %%
# dropping the columns with 75% null values
for i in df.columns:
  if percent[i] > 75:
    df.drop(i, axis=1, inplace=True)
  
# df.head()

# %%
# FILLING NA VALUES WITH MEAN

# extracting the columns names with NA values greater than 10
# group by the categroy to calculate the mean
# filling with mean values
# tlt_null[tlt_null>10].index -> column name

df[tlt_null[tlt_null>10].index] = df.groupby('category')[tlt_null[
    tlt_null>10].index].apply(lambda x: x.fillna(x.mean()))
# Out:
# <ipython-input-11-4514bae01ec9>:8: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df[tlt_null[tlt_null>10].index] = df.groupby('category')[tlt_null[

# %%
df[tlt_null[tlt_null<10].index] = df.groupby('category')[tlt_null[
    tlt_null<10].index].transform(lambda x: x.fillna(method='ffill'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5109 entries, 0 to 5108
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     5109 non-null   string
#  1   category                 5109 non-null   string
#  2   rating                   5109 non-null   float64
#  3   no_reviews               5109 non-null   int64
#  4   sizeMB                   5109 non-null   float64
#  5   size                     5109 non-null   object
#  6   no_of_installs           5109 non-null   object
#  7   type                     5109 non-null   object
#  8   price                    5109 non-null   object
#  9   content_rating           5109 non-null   object
#  10  genres                   5109 non-null   object
#  11  last_updt                5109 non-null   object
#  12  current_ver              5109 non-null   object
#  13  android_ver              5109 non-null   object
# ...

# %%
# df.isnull().sum()

# %%
# nan_rows  = df[df.isnull().any(axis=1)]

# %%
# print(nan_rows)

# %%
# len(df)

# %% [markdown]
# ******************************************************************************

# %% [markdown]
# *   CHANGING THE DATATYPES
# *   DROPPING SOME COLUMNS
# *   CHANGING THE VALUES (Removing + from 500+)

# %%
# Dropping the column 'size' from the dataframe as it is unwanted
df = df.drop(columns = 'size')

# %%
# Replacing the + with '' in no_of_installs
df['no_of_installs'] = df['no_of_installs'].str.replace(r'\D', '')

# Changing the datatype of variable
df['no_of_installs'] = df['no_of_installs'].astype('int')
# Out:
# <ipython-input-19-0bfe30b0a944>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['no_of_installs'] = df['no_of_installs'].str.replace(r'\D', '')

# %%
# Changing the datatype of variable
df['type'] = df['type'].astype('string')

# %%
# Replacing the $ with '' in price
df['price'] = df['price'].str.replace(r'\D', '')

# Changing the datatype of variable
df['price'] = df['price'].astype('float')
# Out:
# <ipython-input-21-21d86949b218>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['price'] = df['price'].str.replace(r'\D', '')

# %%
# Replacing the values
df['content_rating'] = df['content_rating'].replace(['Mature 17+'], ['18+'])
df['content_rating'] = df['content_rating'].replace(['Teen'], ['18+'])
df['content_rating'] = df['content_rating'].replace(['Everyone 10+'], ['10+'])

# Changing the datatype of variable
df['content_rating'] = df['content_rating'].astype('string')

# %%
# Changing the datatype of variable
df['genres'] = df['genres'].astype('string')

# %%
# Changing the datatype of variable
df['last_updt'] = pd.to_datetime(df['last_updt'])

# %%
# Changing the datatype of variable
df['ref_date'] = pd.to_datetime(df['ref_date'])

# %%
# Changing the datatype of variable
df['no_of_days_after_update'] = df['no_of_days_after_update'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5109 entries, 0 to 5108
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     5109 non-null   string
#  1   category                 5109 non-null   string
#  2   rating                   5109 non-null   float64
#  3   no_reviews               5109 non-null   int64
#  4   sizeMB                   5109 non-null   float64
#  5   no_of_installs           5109 non-null   int64
#  6   type                     5109 non-null   string
#  7   price                    5109 non-null   float64
#  8   content_rating           5109 non-null   string
#  9   genres                   5109 non-null   string
#  10  last_updt                5109 non-null   datetime64[ns]
#  11  current_ver              5109 non-null   object
#  12  android_ver              5109 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# name                       0
# category                   0
# rating                     0
# no_reviews                 0
# sizeMB                     0
# no_of_installs             0
# type                       0
# price                      0
# content_rating             0
# genres                     0
# last_updt                  0
# current_ver                0
# android_ver                0
# ref_date                   0
# no_of_days_after_update    0
# dtype: int64

# %%
# converting the continous values to discrete values
# converting categories into two groups POOR and GOOD  (0 and 1)
df['rating_cat'] = pd.cut(df['rating'], bins=[0,4,5], labels=['0', '1'])

# %%
df.isnull().sum()
# Out:
# name                       0
# category                   0
# rating                     0
# no_reviews                 0
# sizeMB                     0
# no_of_installs             0
# type                       0
# price                      0
# content_rating             0
# genres                     0
# last_updt                  0
# current_ver                0
# android_ver                0
# ref_date                   0
# no_of_days_after_update    0
# rating_cat                 0
# dtype: int64

# %%
# dropping null values
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# name                       0
# category                   0
# rating                     0
# no_reviews                 0
# sizeMB                     0
# no_of_installs             0
# type                       0
# price                      0
# content_rating             0
# genres                     0
# last_updt                  0
# current_ver                0
# android_ver                0
# ref_date                   0
# no_of_days_after_update    0
# rating_cat                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5109 entries, 0 to 5108
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     5109 non-null   string
#  1   category                 5109 non-null   string
#  2   rating                   5109 non-null   float64
#  3   no_reviews               5109 non-null   int64
#  4   sizeMB                   5109 non-null   float64
#  5   no_of_installs           5109 non-null   int64
#  6   type                     5109 non-null   string
#  7   price                    5109 non-null   float64
#  8   content_rating           5109 non-null   string
#  9   genres                   5109 non-null   string
#  10  last_updt                5109 non-null   datetime64[ns]
#  11  current_ver              5109 non-null   object
#  12  android_ver              5109 non-null   object
# ...

# %%
# Changing the datatype of variable
df['rating_cat'] = df['rating_cat'].astype('int')

# %%
# dropping the unncessary columns
df = df.drop(['android_ver', 'current_ver'], axis = 1)

# %%
# changing the index value
df. index += 1

# %% [markdown]
# # **Data Exploration and Visualization**

# %%
df.head()
# Out:
#                                                 name category  rating  \
# 1                         Hush - Beauty for Everyone   BEAUTY     4.7
# 2                     ipsy: Makeup, Beauty, and Tips   BEAUTY     4.9
# 3                    Natural recipes for your beauty   BEAUTY     4.7
# 4  BestCam Selfie-selfie, beauty camera, photo ed...   BEAUTY     3.9
# 5                         Mirror - Zoom & Exposure -   BEAUTY     3.9
#
#    no_reviews  sizeMB  no_of_installs  type  price content_rating  genres  \
# 1       18900    17.0          500000  Free    0.0       Everyone  Beauty
# 2       49790    14.0         1000000  Free    0.0       Everyone  Beauty
# 3        1150     9.8          100000  Free    0.0       Everyone  Beauty
# 4        1739    21.0          500000  Free    0.0       Everyone  Beauty
# 5       32090     0.0         1000000  Free    0.0       Everyone  Beauty
#
#    last_updt   ref_date  no_of_days_after_update  rating_cat
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Creating Treemap to check the applicaton which has the highest no. of reviews
fig = px.treemap(df, path=['name'], values='no_reviews')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * Instagram is the most reviewed application among all the other applications.
# * The top five most reviewed applications by the users are instagram, facebook, clash of clans, subway surfers and candy crush saga.
# * Out of all the applications, the games are highly reviewed by users which means they are mostly downloaded android application

# %%
# abstracting the year from the last update column
df['last_updt'] = pd.to_datetime(df['last_updt'])
df['year_column'] = df['last_updt'].dt.year

# %%
# Creating the donut chart which shows the number of applications by year
grouped = df.groupby('year_column')['name'].count()
fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(grouped, labels=grouped.index, autopct='%1.1f%%', startangle=90, counterclock=False, wedgeprops={'width': 0.7})
ax.set_title('No. of Applications by Year')
ax.axis('equal')
plt.show()

# %% [markdown]
# * According to the data, majority of applications were developed in the year 2018 which was around 73%, almost four times that of the combination all the previous year applications.
# * Due to less development in technology, in the early years of the decade, there were fewer less number of applications
# * The number of applications is approximately double by each year.

# %%
# As the data is very larger, it does make any sense to plot scatter plot
pivot_table = df.pivot_table(values='rating', index='name', columns='sizeMB')

# %%
sns.heatmap(pivot_table, cmap='coolwarm')
plt.title('Heatmap of rating vs size(MB)')
plt.xlabel('sizeMB)')
plt.ylabel('name')
plt.show()

# %% [markdown]
# * The graph shows that most the application size is around 26MB on top that it has rating 5
# * There are very less number of application whose size is less than 1MB

# %%
# Creating a bar using the group by function
df_groups = df.groupby(['category'])['no_of_installs'].sum()
df_groups.plot(kind = 'bar')
plt.title('Bar chart of no_of_installs by each category')
plt.xlabel('category')
plt.ylabel('no_of_installs')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# * Game category is booming among the users as they have the highest number of installs.
# * Productivity and social media has almost the same number of installs. Similar scenario could be observed with news & magazines and travel & local applications.
# * Medical, food & drink, and dating applications have the least number of install among all the other categories.

# %%
column_data = df['rating']

# %%
plt.hist(column_data)
plt.xlabel('Ratings of Application')
plt.ylabel('No of Applications')
plt.title('Highest number of reviews among the application')
plt.show()

# %% [markdown]
# * The highest number of ratings among applications is around 4.5, indicating people are enjoying the applications.
# * Hardly few number of users have rated 1 for the applications.
# * Meanwhile some people have also preferred 5 rating to applications. This shows that companies are giving their best efforts in making the applications.

# %% [markdown]
# # **Model Selection**

# %%
df.head()
# Out:
#                                                 name category  rating  \
# 1                         Hush - Beauty for Everyone   BEAUTY     4.7
# 2                     ipsy: Makeup, Beauty, and Tips   BEAUTY     4.9
# 3                    Natural recipes for your beauty   BEAUTY     4.7
# 4  BestCam Selfie-selfie, beauty camera, photo ed...   BEAUTY     3.9
# 5                         Mirror - Zoom & Exposure -   BEAUTY     3.9
#
#    no_reviews  sizeMB  no_of_installs  type  price content_rating  genres  \
# 1       18900    17.0          500000  Free    0.0       Everyone  Beauty
# 2       49790    14.0         1000000  Free    0.0       Everyone  Beauty
# 3        1150     9.8          100000  Free    0.0       Everyone  Beauty
# 4        1739    21.0          500000  Free    0.0       Everyone  Beauty
# 5       32090     0.0         1000000  Free    0.0       Everyone  Beauty
#
#    last_updt   ref_date  no_of_days_after_update  rating_cat  year_column
# ...

# %%
# generating descriptive statistics
df.describe(include='all')
# Out:
# <ipython-input-48-c75257391a5f>:2: FutureWarning:
#
# Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#
# <ipython-input-48-c75257391a5f>:2: FutureWarning:
#
# Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#               name category       rating    no_reviews       sizeMB  \
# count         5109     5109  5109.000000  5.109000e+03  5109.000000
# unique        4381       16          NaN           NaN          NaN
# top     Bowmasters     GAME          NaN           NaN          NaN
# freq             6     1130          NaN           NaN          NaN
# ...

# %%
# !pip install dmba
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 49.0 MB/s eta 0:00:00
# ...

# %%
pip install scikit-plot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# importing libraries
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
# from sklearn.metrics import plot_cumulative_gain
from scikitplot.metrics import plot_cumulative_gain

import matplotlib
import matplotlib.pylab as plt

import dmba
from dmba import classificationSummary, gainsChart, regressionSummary
# Out:
# no display found. Using non-interactive Agg backend

# %%
# Split the data into training and testing sets
X = df.drop(columns=["rating", "name", "last_updt", "ref_date", "year_column", 
                     "category", "type", "content_rating",  "genres", 
                     "rating_cat"])
y = df["rating_cat"]
classes = [ 'Poor', 'Good']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.4, 
                                                    random_state=1)

# %% [markdown]
# # k-NN

# %%
# Create KNN model with k=2
knn = KNeighborsClassifier(n_neighbors=2)

# %%
# Train the model using the training data
model = knn.fit(X_train, y_train)

# %%
, KernelDensity
predProb_train = knn.predict_proba(X_train)
predProb_valid = knn.predict_proba(X_valid)

# %%
y_valid_pred = knn.predict(X_valid)
y_train_pred = knn.predict(X_train)

# %%
# # plot the gains chart
# y_probas = model.predict_proba(X_valid)
# plot_cumulative_gain(y_valid, y_probas)

# %%
# # y_test contains true labels and y_pred contains predicted labels
# tn, fp, fn, tp = confusion_matrix(y_valid, y_valid_pred).ravel()

# # Calculate TPR
# tpr = tp / (tp + fn)

# %%
classificationSummary(y_train, y_train_pred, class_names = classes)
# Out:
# Confusion Matrix (Accuracy 0.8737)
#
#        Prediction
# Actual Poor Good
#   Poor  723    0
#   Good  387 1955

# %%
classificationSummary(y_valid, y_valid_pred, class_names=classes)
# Out:
# Confusion Matrix (Accuracy 0.6962)
#
#        Prediction
# Actual Poor Good
#   Poor  274  193
#   Good  428 1149

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# calculate precision, recall, and F1-score
precision = precision_score(y_valid, y_valid_pred)
recall = recall_score(y_valid, y_valid_pred)
f1 = f1_score(y_valid, y_valid_pred)

# print the results
print('Precision: {:.3f}'.format(precision))
print('Recall: {:.3f}'.format(recall))
print('F1-score: {:.3f}'.format(f1))
# Out:
# Precision: 0.856
# Recall: 0.729
# F1-score: 0.787

# %%
# %matplotlib inline
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# predict class probabilities for test set
y_pred_prob = model.predict_proba(X_valid)[:, 1]

# calculate the AUC score
auc_score = roc_auc_score(y_valid, y_pred_prob)

# calculate the ROC curve
fpr1, tpr1, thresholds = roc_curve(y_valid, y_pred_prob)

# plot the ROC curve
plt.plot(fpr1, tpr1, label=f'AUC = {auc_score:.3f}')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
# %matplotlib inline
# df_dtr = pd.DataFrame({'actual': 1-y_valid.cat.codes, 'prob': predProb_valid[:,0]})
# df_dtr = df_dtr.sort_values(by = ['prob'], 
#                             ascending = False).reset_index(drop = True)
# fig, ax = plt.subplots()
# fig.set_size_inches(4,4)
# gainsChart(df_dtr.prob,ax=ax)

# plt.tight_layout()
# plt.show()

# %% [markdown]
# *****************************************************************************

# %% [markdown]
# ************************************************************************

# %% [markdown]
# # Naive Bayes

# %%
nb = MultinomialNB(alpha = 0.01)

# %%
model = nb.fit(X_train, y_train)

# %%
predProb_train = nb.predict_proba(X_train)
predProb_valid = nb.predict_proba(X_valid)

# %%
y_valid_pred = nb.predict(X_valid)
y_train_pred = nb.predict(X_train)

# %%
# # plot the gains chart
# y_probas = model.predict_proba(X_valid)
# plot_cumulative_gain(y_valid, y_probas)

# %%
classificationSummary(y_train, y_train_pred, class_names = classes)
# Out:
# Confusion Matrix (Accuracy 0.4783)
#
#        Prediction
# Actual Poor Good
#   Poor  630   93
#   Good 1506  836

# %%
classificationSummary(y_valid, y_valid_pred, class_names=classes)
# Out:
# Confusion Matrix (Accuracy 0.4971)
#
#        Prediction
# Actual Poor Good
#   Poor  395   72
#   Good  956  621

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# calculate precision, recall, and F1-score
precision = precision_score(y_valid, y_valid_pred)
recall = recall_score(y_valid, y_valid_pred)
f1 = f1_score(y_valid, y_valid_pred)

# print the results
print('Precision: {:.3f}'.format(precision))
print('Recall: {:.3f}'.format(recall))
print('F1-score: {:.3f}'.format(f1))
# Out:
# Precision: 0.896
# Recall: 0.394
# F1-score: 0.547

# %%
# %matplotlib inline
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# predict class probabilities for test set
y_pred_prob = model.predict_proba(X_valid)[:, 1]

# calculate the AUC score
auc_score = roc_auc_score(y_valid, y_pred_prob)

# calculate the ROC curve
fpr2, tpr2, thresholds = roc_curve(y_valid, y_pred_prob)

# plot the ROC curve
plt.plot(fpr2, tpr2, label=f'AUC = {auc_score:.3f}')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# **# Logistic Regression**

# %%
# create a logistic regression object
log_reg = LogisticRegression()

# %%
# train the model on the training data
model = log_reg.fit(X_train, y_train)

# %%
predProb_train = log_reg.predict_proba(X_train)
predProb_valid = log_reg.predict_proba(X_valid)

# %%
y_valid_pred = log_reg.predict(X_valid)
y_train_pred = log_reg.predict(X_train)

# %%
# # plot the gains chart
# y_probas = model.predict_proba(X_valid)
# plot_cumulative_gain(y_valid, y_probas)

# %%
classificationSummary(y_train, y_train_pred, class_names = classes)
# Out:
# Confusion Matrix (Accuracy 0.7641)
#
#        Prediction
# Actual Poor Good
#   Poor    4  719
#   Good    4 2338

# %%
classificationSummary(y_valid, y_valid_pred, class_names=classes)
# Out:
# Confusion Matrix (Accuracy 0.7715)
#
#        Prediction
# Actual Poor Good
#   Poor    5  462
#   Good    5 1572

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# calculate precision, recall, and F1-score
precision = precision_score(y_valid, y_valid_pred)
recall = recall_score(y_valid, y_valid_pred)
f1 = f1_score(y_valid, y_valid_pred)

# print the results
print('Precision: {:.3f}'.format(precision))
print('Recall: {:.3f}'.format(recall))
print('F1-score: {:.3f}'.format(f1))
# Out:
# Precision: 0.773
# Recall: 0.997
# F1-score: 0.871

# %%
# %matplotlib inline
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# predict class probabilities for test set
y_pred_prob = model.predict_proba(X_valid)[:, 1]

# calculate the AUC score
auc_score = roc_auc_score(y_valid, y_pred_prob)

# calculate the ROC curve
fpr3, tpr3, thresholds = roc_curve(y_valid, y_pred_prob)

# plot the ROC curve
plt.plot(fpr3, tpr3, label=f'AUC = {auc_score:.3f}')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# # CART

# %%
# train the decision tree classifier
dt = DecisionTreeClassifier()

# %%
# train the model on the training data
model = dt.fit(X_train, y_train)

# %%
predProb_train = dt.predict_proba(X_train)
predProb_valid = dt.predict_proba(X_valid)

# %%
y_valid_pred = dt.predict(X_valid)
y_train_pred = dt.predict(X_train)

# %%
classificationSummary(y_train, y_train_pred, class_names = classes)
# Out:
# Confusion Matrix (Accuracy 1.0000)
#
#        Prediction
# Actual Poor Good
#   Poor  723    0
#   Good    0 2342

# %%
classificationSummary(y_valid, y_valid_pred, class_names=classes)
# Out:
# Confusion Matrix (Accuracy 0.7529)
#
#        Prediction
# Actual Poor Good
#   Poor  216  251
#   Good  254 1323

# %%
# # plot the gains chart
# y_probas = dt.predict_proba(X_valid)
# plot_cumulative_gain(y_valid, y_probas)

# %%
# evaluate the model
accuracy = accuracy_score(y_valid, y_valid_pred)
conf_matrix = confusion_matrix(y_valid, y_valid_pred)
print(f"Accuracy: {accuracy}\nConfusion Matrix: \n{conf_matrix}")
# Out:
# Accuracy: 0.75293542074364
# Confusion Matrix:
# [[ 216  251]
#  [ 254 1323]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# calculate precision, recall, and F1-score
precision = precision_score(y_valid, y_valid_pred)
recall = recall_score(y_valid, y_valid_pred)
f1 = f1_score(y_valid, y_valid_pred)

# print the results
print('Precision: {:.3f}'.format(precision))
print('Recall: {:.3f}'.format(recall))
print('F1-score: {:.3f}'.format(f1))
# Out:
# Precision: 0.841
# Recall: 0.839
# F1-score: 0.840

# %%
# %matplotlib inline
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# predict class probabilities for test set
y_pred_prob = model.predict_proba(X_valid)[:, 1]

# calculate the AUC score
auc_score = roc_auc_score(y_valid, y_pred_prob)

# calculate the ROC curve
fpr4, tpr4, thresholds = roc_curve(y_valid, y_pred_prob)

# plot the ROC curve
plt.plot(fpr4, tpr4, label=f'AUC = {auc_score:.3f}')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# # Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
# create a Discriminant Analysis object
lda = LinearDiscriminantAnalysis()

# %%
# train the model on the training data
model = lda.fit(X_train, y_train)

# %%
predProb_train = lda.predict_proba(X_train)
predProb_valid = lda.predict_proba(X_valid)

# %%
y_valid_pred = lda.predict(X_valid)
y_train_pred = lda.predict(X_train)

# %%
# # plot the gains chart
# y_probas = lda.predict_proba(X_valid)
# plot_cumulative_gain(y_valid, y_probas)

# %%
classificationSummary(y_train, y_train_pred, class_names = classes)
# Out:
# Confusion Matrix (Accuracy 0.7644)
#
#        Prediction
# Actual Poor Good
#   Poor    8  715
#   Good    7 2335

# %%
classificationSummary(y_valid, y_valid_pred, class_names=classes)
# Out:
# Confusion Matrix (Accuracy 0.7720)
#
#        Prediction
# Actual Poor Good
#   Poor    4  463
#   Good    3 1574

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# calculate precision, recall, and F1-score
precision = precision_score(y_valid, y_valid_pred)
recall = recall_score(y_valid, y_valid_pred)
f1 = f1_score(y_valid, y_valid_pred)

# print the results
print('Precision: {:.3f}'.format(precision))
print('Recall: {:.3f}'.format(recall))
print('F1-score: {:.3f}'.format(f1))
# Out:
# Precision: 0.773
# Recall: 0.998
# F1-score: 0.871

# %%
# %matplotlib inline
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# predict class probabilities for test set
y_pred_prob = model.predict_proba(X_valid)[:, 1]

# calculate the AUC score
auc_score = roc_auc_score(y_valid, y_pred_prob)

# calculate the ROC curve
fpr5, tpr5, thresholds = roc_curve(y_valid, y_pred_prob)

# plot the ROC curve
plt.plot(fpr5, tpr5, label=f'AUC = {auc_score:.3f}')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# # Neural Network

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf = MLPClassifier(hidden_layer_sizes=(3), activation='logistic', 
                    solver='lbfgs', random_state=1)

# %%
# train the model on the training data
model = clf.fit(X_train, y_train)

# %%
y_valid_pred = clf.predict(X_valid)
y_train_pred = clf.predict(X_train)

# %%
classificationSummary(y_train, y_train_pred, class_names = classes)
# Out:
# Confusion Matrix (Accuracy 0.7638)
#
#        Prediction
# Actual Poor Good
#   Poor    3  720
#   Good    4 2338

# %%
classificationSummary(y_valid, y_valid_pred, class_names=classes)
# Out:
# Confusion Matrix (Accuracy 0.7705)
#
#        Prediction
# Actual Poor Good
#   Poor    1  466
#   Good    3 1574

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# calculate precision, recall, and F1-score
precision = precision_score(y_valid, y_valid_pred)
recall = recall_score(y_valid, y_valid_pred)
f1 = f1_score(y_valid, y_valid_pred)

# print the results
print('Precision: {:.3f}'.format(precision))
print('Recall: {:.3f}'.format(recall))
print('F1-score: {:.3f}'.format(f1))
# Out:
# Precision: 0.772
# Recall: 0.998
# F1-score: 0.870

# %%
# %matplotlib inline
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# predict class probabilities for test set
y_pred_prob = model.predict_proba(X_valid)[:, 1]

# calculate the AUC score
auc_score = roc_auc_score(y_valid, y_pred_prob)

# calculate the ROC curve
fpr6, tpr6, thresholds = roc_curve(y_valid, y_pred_prob)

# plot the ROC curve
plt.plot(fpr6, tpr6, label=f'AUC = {auc_score:.3f}')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# # Random Forest - Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Initialize and train the random forest classifier
rf = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)

# %%
model = rf.fit(X_train, y_train)

# %%
y_valid_pred = rf.predict(X_valid)
y_train_pred = rf.predict(X_train)

# %%
classificationSummary(y_train, y_train_pred, class_names = classes)
# Out:
# Confusion Matrix (Accuracy 0.8669)
#
#        Prediction
# Actual Poor Good
#   Poor  321  402
#   Good    6 2336

# %%
classificationSummary(y_valid, y_valid_pred, class_names=classes)
# Out:
# Confusion Matrix (Accuracy 0.7813)
#
#        Prediction
# Actual Poor Good
#   Poor   69  398
#   Good   49 1528

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# calculate precision, recall, and F1-score
precision = precision_score(y_valid, y_valid_pred)
recall = recall_score(y_valid, y_valid_pred)
f1 = f1_score(y_valid, y_valid_pred)

# print the results
print('Precision: {:.3f}'.format(precision))
print('Recall: {:.3f}'.format(recall))
print('F1-score: {:.3f}'.format(f1))
# Out:
# Precision: 0.793
# Recall: 0.969
# F1-score: 0.872

# %%
# %matplotlib inline
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# predict class probabilities for test set
y_pred_prob = model.predict_proba(X_valid)[:, 1]

# calculate the AUC score
auc_score = roc_auc_score(y_valid, y_pred_prob)

# calculate the ROC curve
fpr7, tpr7, thresholds = roc_curve(y_valid, y_pred_prob)

# plot the ROC curve
plt.plot(fpr7, tpr7, label=f'AUC = {auc_score:.3f}')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# # ALL

# %%
# %matplotlib inline
# plot the ROC curve
plt.plot(fpr1, tpr1,  label = 'k-NN')
plt.plot(fpr2, tpr2, label = 'Naive Bayes')
plt.plot(fpr3, tpr3, label = 'Logistic Regression')
plt.plot(fpr4, tpr4, label = 'CART')
plt.plot(fpr5, tpr5, label = 'Discriminant Analysis')
plt.plot(fpr6, tpr6, label = 'Neural Net')
plt.plot(fpr7, tpr7, label = 'Random Forest - Classifier')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()
